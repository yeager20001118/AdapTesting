# %% [markdown]
# ## Demo for tst in the tabular data

# %%
from adaptesting import tst # Load the main library to conduct tst

# Generate data as example, make sure the input data should be Pytorch Tensor
import torch
import random
import time
from torch.distributions import MultivariateNormal

start = time.time()
torch.manual_seed(0)
random.seed(0)

if torch.cuda.is_available():
    device = torch.device("cuda:0")
# elif torch.backends.mps.is_available(): # mps cannot work well on Apple M Silicon
#     device = torch.device("mps")
else:
    device = torch.device("cpu")

mean = torch.tensor([0.5, 0.5])
cov1 = torch.tensor([[1.0, 0.5], [0.5, 1.0]])
cov2 = torch.tensor([[1.0, 0], [0, 1.0]])
mvn1 = MultivariateNormal(mean, cov1)
mvn2 = MultivariateNormal(mean, cov2)

counter = 0
n_trial = 100
n_samples = 250

# Conduct Experiments for n_trial times, 
# remove the for loop if only want to get a result of reject or not
for _ in range(n_trial):

    # Uncomment Z2 with same distribution to test Type-I error
    Z1 = mvn1.sample((1000,))
    Z2 = mvn2.sample((1000,))  # Test power
    # Z2 = mvn1.sample((1000,))  # Type-I error

    # Create a list of indices from 0 to 1000
    indices = list(range(1000))

    # Shuffle the indices
    random.shuffle(indices)

    # Select the n_samples for X
    X_indices = indices[:n_samples]

    # Select the n_samples for Y
    # Y_indices = indices[:n_samples]

    # Sample X and Y from Z using the selected indices, 
    # X.size() = (n_samples, 2), Y.size() = (n_samples, 2)
    X = Z1[X_indices]
    Y = Z2[X_indices]

    # Five kinds of SOTA TST methods to choose
    h, _, _ = tst(X, Y, device=device) # default method is median heuristic
    # h, _, _ = tst(X, Y, device=device, method="fuse", kernel="laplace_gaussian", n_perm=2000)
    # h, _, _ = tst(X, Y, device=device, method="agg", n_perm=3000)
    # h, _, _ = tst(X, Y, device=device, method="clf", data_type="tabular", patience=150, n_perm=200)
    # h, _, _ = tst(X, Y, device=device, method="deep", data_type="tabular", patience=150, n_perm=200)
    counter += h

print(f"Power: {counter}/{n_trial}")
end = time.time()
print(f"Time taken: {end - start:.4f} seconds")
# Out:
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0061.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0064.
# Fail to reject the null hypothesis with p-value: 0.1584, the test statistics for median is 0.0026.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0076.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0042.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0071.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0039.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0037.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0123.
# Fail to reject the null hypothesis with p-value: 0.0792, the test statistics for median is 0.0041.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0044.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0080.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0041.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0120.
# Reject the null hypothesis with p-value: 0.0495, the test statistics for median is 0.0044.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0075.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0074.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0064.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0049.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0107.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0076.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0060.
# Fail to reject the null hypothesis with p-value: 0.0990, the test statistics for median is 0.0027.
# Fail to reject the null hypothesis with p-value: 0.2277, the test statistics for median is 0.0006.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0112.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0065.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0044.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0082.
# Fail to reject the null hypothesis with p-value: 0.1089, the test statistics for median is 0.0038.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0037.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0132.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0101.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0094.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0066.
# Fail to reject the null hypothesis with p-value: 0.1089, the test statistics for median is 0.0030.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0125.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0103.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0035.
# Fail to reject the null hypothesis with p-value: 0.0990, the test statistics for median is 0.0023.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0060.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0066.
# Fail to reject the null hypothesis with p-value: 0.0792, the test statistics for median is 0.0041.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0051.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0076.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0102.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0078.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0052.
# Reject the null hypothesis with p-value: 0.0495, the test statistics for median is 0.0048.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0094.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0076.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0050.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0118.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0063.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0104.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0078.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0073.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0025.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0064.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0072.
# Fail to reject the null hypothesis with p-value: 0.2376, the test statistics for median is 0.0015.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0051.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0072.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0041.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0050.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0061.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0094.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0055.
# Reject the null hypothesis with p-value: 0.0495, the test statistics for median is 0.0052.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0062.
# Fail to reject the null hypothesis with p-value: 0.1386, the test statistics for median is 0.0034.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0061.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0063.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0095.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0040.
# Fail to reject the null hypothesis with p-value: 0.1881, the test statistics for median is 0.0012.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0090.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0120.
# Reject the null hypothesis with p-value: 0.0198, the test statistics for median is 0.0094.
# Fail to reject the null hypothesis with p-value: 0.0990, the test statistics for median is 0.0043.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0063.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0097.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0073.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0090.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0059.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0080.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0063.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0098.
# Fail to reject the null hypothesis with p-value: 0.2673, the test statistics for median is 0.0005.
# Fail to reject the null hypothesis with p-value: 0.0990, the test statistics for median is 0.0033.
# Fail to reject the null hypothesis with p-value: 0.0594, the test statistics for median is 0.0043.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0101.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0097.
# Reject the null hypothesis with p-value: 0.0297, the test statistics for median is 0.0057.
# Fail to reject the null hypothesis with p-value: 0.0693, the test statistics for median is 0.0056.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0071.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0122.
# Reject the null hypothesis with p-value: 0.0396, the test statistics for median is 0.0071.
# Fail to reject the null hypothesis with p-value: 0.0792, the test statistics for median is 0.0044.
# Reject the null hypothesis with p-value: 0.0099, the test statistics for median is 0.0092.
# Fail to reject the null hypothesis with p-value: 0.1188, the test statistics for median is 0.0043.
# Power: 69/100
# Time taken: 4.2299 seconds

# %% [markdown]
# ### Performance display after running 100 trials of different input samples
#
# | Method       | Median | MMD-FUSE | MMD-Agg | MMD-Deep | C2ST-MMD |
# | ------------ | ------ | -------- | ------- | -------- | -------- |
# | Test Power   | 0.69   | 0.56     | 0.72    | 0.72     | 0.71     |
# | Type-I Error | 0.01   | 0.03     | 0.04    | 0.05     | 0.06     |
# | Runtime (s)  | 4.49   | 10.14    | 3.48    | 486.81   | 570.94   |
