# %% [markdown]
# ## Demo for tst in the tabular data

# %%
from adaptesting import tst # Load the main library to conduct tst

# Generate data as example, make sure the input data should be Pytorch Tensor
import torch
import random
import time
from torch.distributions import MultivariateNormal

start = time.time()
torch.manual_seed(0)
random.seed(0)

if torch.cuda.is_available():
    device = torch.device("cuda:0")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

mean = torch.tensor([0.5, 0.5])
cov1 = torch.tensor([[1.0, 0.5], [0.5, 1.0]])
cov2 = torch.tensor([[1.0, 0], [0, 1.0]])
mvn1 = MultivariateNormal(mean, cov1)
mvn2 = MultivariateNormal(mean, cov2)

counter = 0
n_trial = 100
n_samples = 250

# Conduct Experiments for n_trial times, 
# remove the for loop if only want to get a result of reject or not
for _ in range(n_trial):

    # Uncomment Z2 with same distribution to test Type-I error
    Z1 = mvn1.sample((1000,))
    Z2 = mvn2.sample((1000,))  # Test power
    # Z2 = mvn1.sample((1000,))  # Type-I error

    # Create a list of indices from 0 to 1000
    indices = list(range(1000))

    # Shuffle the indices
    random.shuffle(indices)

    # Select the n_samples for X
    X_indices = indices[:n_samples]

    # Select the n_samples for Y
    # Y_indices = indices[:n_samples]

    # Sample X and Y from Z using the selected indices, 
    # X.size() = (n_samples, 2), Y.size() = (n_samples, 2)
    X = Z1[X_indices]
    Y = Z2[X_indices]

    # Five kinds of SOTA TST methods to choose
    h, _, _ = tst(X, Y, device=device) # default method is median heuristic
    # h, _, _ = tst(X, Y, device=device, method="fuse", kernel="laplace_gaussian", n_perm=2000)
    # h, _, _ = tst(X, Y, device=device, method="agg", n_perm=3000)
    # h, _, _ = tst(X, Y, device=device, method="clf", data_type="tabular", patience=150, n_perm=200)
    # h, _, _ = tst(X, Y, device=device, method="deep", data_type="tabular", patience=150, n_perm=200)
    counter += h

print(f"Power: {counter}/{n_trial}")
end = time.time()
print(f"Time taken: {end - start:.4f} seconds")
# Out:
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.0060651302337646484.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.008074045181274414.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.0069904327392578125.
# Fail to reject the null hypothesis with p-value: 0.1, the MMD value is 0.0027581453323364258.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.00699925422668457.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.009712934494018555.
# Fail to reject the null hypothesis with p-value: 0.11, the MMD value is 0.004103302955627441.
# Fail to reject the null hypothesis with p-value: 0.07, the MMD value is 0.0034340620040893555.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.006949901580810547.
# Reject the null hypothesis with p-value: 0.04, the MMD value is 0.005875945091247559.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.013964414596557617.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.008929610252380371.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.005191922187805176.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.010296344757080078.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.005185723304748535.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.007323026657104492.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.011825799942016602.
# Fail to reject the null hypothesis with p-value: 0.07, the MMD value is 0.003112316131591797.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.010053873062133789.
# Fail to reject the null hypothesis with p-value: 0.11, the MMD value is 0.0026731491088867188.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.010680794715881348.
# Fail to reject the null hypothesis with p-value: 0.12, the MMD value is 0.0027614831924438477.
# Fail to reject the null hypothesis with p-value: 0.1, the MMD value is 0.0046776533126831055.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.008559465408325195.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.005547523498535156.
# Fail to reject the null hypothesis with p-value: 0.06, the MMD value is 0.0028226375579833984.
# Fail to reject the null hypothesis with p-value: 0.2, the MMD value is 0.0016703605651855469.
# Fail to reject the null hypothesis with p-value: 0.06, the MMD value is 0.0027801990509033203.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.007837772369384766.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.0064814090728759766.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.007893919944763184.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.006977438926696777.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.0057947635650634766.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.005885481834411621.
# Fail to reject the null hypothesis with p-value: 0.24, the MMD value is 0.0012775659561157227.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.008710265159606934.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.004828095436096191.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.008839130401611328.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.008018851280212402.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.011830806732177734.
# Fail to reject the null hypothesis with p-value: 0.07, the MMD value is 0.005177497863769531.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.006554007530212402.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.00704646110534668.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.004607439041137695.
# Fail to reject the null hypothesis with p-value: 0.06, the MMD value is 0.0050612688064575195.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.006090998649597168.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.00813591480255127.
# Fail to reject the null hypothesis with p-value: 0.06, the MMD value is 0.005050301551818848.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.005452275276184082.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.009408116340637207.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.007854461669921875.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.016972899436950684.
# Reject the null hypothesis with p-value: 0.04, the MMD value is 0.0064640045166015625.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.005105376243591309.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.0061187744140625.
# Fail to reject the null hypothesis with p-value: 0.08, the MMD value is 0.0027256011962890625.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.007512927055358887.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.007941961288452148.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.003882884979248047.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.007940530776977539.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.008621692657470703.
# Reject the null hypothesis with p-value: 0.04, the MMD value is 0.0056993961334228516.
# Fail to reject the null hypothesis with p-value: 0.16, the MMD value is 0.0026712417602539062.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.012408852577209473.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.008263230323791504.
# Fail to reject the null hypothesis with p-value: 0.07, the MMD value is 0.00318145751953125.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.010558605194091797.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.011984825134277344.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.006112098693847656.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.009245514869689941.
# Fail to reject the null hypothesis with p-value: 0.07, the MMD value is 0.004971146583557129.
# Reject the null hypothesis with p-value: 0.04, the MMD value is 0.005190849304199219.
# Fail to reject the null hypothesis with p-value: 0.09, the MMD value is 0.0034067630767822266.
# Fail to reject the null hypothesis with p-value: 0.27, the MMD value is 0.0015411376953125.
# Fail to reject the null hypothesis with p-value: 0.07, the MMD value is 0.0047539472579956055.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.009350061416625977.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.005643129348754883.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.0049364566802978516.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.01012277603149414.
# Reject the null hypothesis with p-value: 0.04, the MMD value is 0.0048542022705078125.
# Fail to reject the null hypothesis with p-value: 0.16, the MMD value is 0.0028940439224243164.
# Fail to reject the null hypothesis with p-value: 0.39, the MMD value is 0.0008171796798706055.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.006115913391113281.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.007669925689697266.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.008150339126586914.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.006460666656494141.
# Fail to reject the null hypothesis with p-value: 0.12, the MMD value is 0.0025550127029418945.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.006955981254577637.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.009543061256408691.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.00791478157043457.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.006596565246582031.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.005112171173095703.
# Fail to reject the null hypothesis with p-value: 0.26, the MMD value is 0.0011599063873291016.
# Fail to reject the null hypothesis with p-value: 0.16, the MMD value is 0.0024529695510864258.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.007227540016174316.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.012704253196716309.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.013083338737487793.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.006762862205505371.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.008066534996032715.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.009116172790527344.
# Power: 68/100

# %% [markdown]
# ### Performance display after running 100 trials of different input samples
#
# | Method       | Median | MMD-FUSE | MMD-Agg | MMD-Deep | C2ST-MMD |
# | ------------ | ------ | -------- | ------- | -------- | -------- |
# | Test Power   | 0.69   | 0.56     | 0.72    | 0.72     | 0.71     |
# | Type-I Error | 0.01   | 0.03     | 0.04    | 0.05     | 0.06     |
# | Runtime (s)  | 4.49   | 10.14    | 3.48    | 486.81   | 570.94   |
