# %% [markdown]
# ## Demo for tst in the text data

# %%
from adaptesting import tst # Load the main library to conduct tst

# Load HC3 data as example, the input text data could be either list of strings ["text1", "text2", ...] 
# or embeddings of the text data in the form of Pytorch Tensor
import torch
import random
import time
from datasets import load_dataset
from transformers import logging

logging.set_verbosity_error()  # This will hide the warning

start = time.time()
torch.manual_seed(0)
random.seed(0)

if torch.cuda.is_available():
    device = torch.device("cuda:0")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")

dataset = load_dataset("Hello-SimpleAI/HC3", "all")

filtered_dataset = dataset['train'].filter(
    lambda x: x['source'] == 'medicine')  # 1248 samples

def flatten(list_of_lists):
    # Flatten a list of lists where each inner list contains one string
    return [item for sublist in list_of_lists for item in sublist]

# Text data from huggingface has a form of [["text1"], ["text2"], ...], flatten it
Z1 = flatten(filtered_dataset["chatgpt_answers"])
Z2 = flatten(filtered_dataset["human_answers"])  # Test power
# Z2 = Z1  # Type-I error

counter = 0
n_trial = 100
n_samples = 100

# Conduct Experiments for n_trial times,
# remove the for loop if only want to get a result of reject or not
for _ in range(n_trial):

    # Sample X and Y from Z using the selected indices
    random.shuffle(Z1)
    X = Z1[:n_samples]

    random.shuffle(Z2)
    Y = Z2[:n_samples]

    # Five kinds of SOTA TST methods to choose
    # !!! Must input data type as "text" for text data !!!
    h, _, _ = tst(X, Y, device=device, data_type="text")  # default method is median heuristic
    # h, _, _ = tst(X, Y, device=device, method="fuse", data_type="text", kernel="laplace_gaussian", n_perm=2000)
    # h, _, _ = tst(X, Y, device=device, method="agg", data_type="text", n_perm=3000)
    # h, _, _ = tst(X, Y, device=device, method="clf", data_type="text", patience=150, n_perm=200)
    # h, _, _ = tst(X, Y, device=device, method="deep", data_type="text", patience=150, n_perm=200)
    counter += h

print(f"Power: {counter}/{n_trial}")
end = time.time()
print(f"Time taken: {end - start:.4f} seconds")
# Out:
# Fail to reject the null hypothesis with p-value: 0.29, the MMD value is 0.0018093585968017578.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.052556753158569336.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.019411563873291016.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.018266797065734863.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.00862109661102295.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.05629551410675049.
# Fail to reject the null hypothesis with p-value: 0.5, the MMD value is -0.0006477832794189453.
# Fail to reject the null hypothesis with p-value: 0.06, the MMD value is 0.00481569766998291.
# Fail to reject the null hypothesis with p-value: 0.62, the MMD value is -0.002126932144165039.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.018361926078796387.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.03613781929016113.
# Fail to reject the null hypothesis with p-value: 0.34, the MMD value is 0.00015163421630859375.
# Fail to reject the null hypothesis with p-value: 0.72, the MMD value is -0.0022623538970947266.
# Fail to reject the null hypothesis with p-value: 0.36, the MMD value is -9.071826934814453e-05.
# Fail to reject the null hypothesis with p-value: 0.54, the MMD value is -0.0009942054748535156.
# Fail to reject the null hypothesis with p-value: 0.61, the MMD value is -0.0016628503799438477.
# Fail to reject the null hypothesis with p-value: 0.17, the MMD value is 0.002088785171508789.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.05468952655792236.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.07297384738922119.
# Fail to reject the null hypothesis with p-value: 0.12, the MMD value is 0.003938913345336914.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.059027910232543945.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.019986867904663086.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.030609965324401855.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.02176356315612793.
# Fail to reject the null hypothesis with p-value: 0.17, the MMD value is 0.0037544965744018555.
# Fail to reject the null hypothesis with p-value: 0.09, the MMD value is 0.004095554351806641.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.07509613037109375.
# Reject the null hypothesis with p-value: 0.04, the MMD value is 0.010255575180053711.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.06161236763000488.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.015398025512695312.
# Fail to reject the null hypothesis with p-value: 0.58, the MMD value is -0.0013495683670043945.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.013315081596374512.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.022558927536010742.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.00929415225982666.
# Fail to reject the null hypothesis with p-value: 0.99, the MMD value is -0.005003213882446289.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.017598628997802734.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.06428468227386475.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.019680500030517578.
# Fail to reject the null hypothesis with p-value: 0.23, the MMD value is 0.0030171871185302734.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.007760286331176758.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.00844430923461914.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.05481290817260742.
# Fail to reject the null hypothesis with p-value: 0.09, the MMD value is 0.004259586334228516.
# Fail to reject the null hypothesis with p-value: 0.91, the MMD value is -0.004217028617858887.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.05097818374633789.
# Fail to reject the null hypothesis with p-value: 0.28, the MMD value is 0.0010116100311279297.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.027378559112548828.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.008573412895202637.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.008566617965698242.
# Fail to reject the null hypothesis with p-value: 0.89, the MMD value is -0.003828763961791992.
# Fail to reject the null hypothesis with p-value: 0.49, the MMD value is -0.0009039640426635742.
# Fail to reject the null hypothesis with p-value: 0.06, the MMD value is 0.008462905883789062.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.013637661933898926.
# Fail to reject the null hypothesis with p-value: 0.81, the MMD value is -0.0032367706298828125.
# Fail to reject the null hypothesis with p-value: 0.09, the MMD value is 0.0041255950927734375.
# Fail to reject the null hypothesis with p-value: 0.14, the MMD value is 0.004067540168762207.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.01872420310974121.
# Fail to reject the null hypothesis with p-value: 0.05, the MMD value is 0.006904959678649902.
# Fail to reject the null hypothesis with p-value: 0.95, the MMD value is -0.00403285026550293.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.029265642166137695.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.015501856803894043.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.08779215812683105.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.014714956283569336.
# Fail to reject the null hypothesis with p-value: 0.22, the MMD value is 0.0028063058853149414.
# Fail to reject the null hypothesis with p-value: 0.09, the MMD value is 0.004399299621582031.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.03166496753692627.
# Fail to reject the null hypothesis with p-value: 0.15, the MMD value is 0.0044525861740112305.
# Fail to reject the null hypothesis with p-value: 0.1, the MMD value is 0.0053452253341674805.
# Fail to reject the null hypothesis with p-value: 0.56, the MMD value is -0.0012547969818115234.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.014411568641662598.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.025621652603149414.
# Reject the null hypothesis with p-value: 0.02, the MMD value is 0.014934897422790527.
# Fail to reject the null hypothesis with p-value: 0.41, the MMD value is -0.0006427764892578125.
# Fail to reject the null hypothesis with p-value: 0.17, the MMD value is 0.0032973289489746094.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.033632874488830566.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.02226114273071289.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.03750348091125488.
# Fail to reject the null hypothesis with p-value: 0.99, the MMD value is -0.004625201225280762.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.011828184127807617.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.007846593856811523.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.0423663854598999.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.022707819938659668.
# Fail to reject the null hypothesis with p-value: 0.93, the MMD value is -0.0038328170776367188.
# Reject the null hypothesis with p-value: 0.03, the MMD value is 0.006317019462585449.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.0711296796798706.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.015407323837280273.
# Fail to reject the null hypothesis with p-value: 0.26, the MMD value is 0.001370072364807129.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.020003199577331543.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.013726949691772461.
# Fail to reject the null hypothesis with p-value: 0.88, the MMD value is -0.0031186342239379883.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.04817628860473633.
# Fail to reject the null hypothesis with p-value: 0.26, the MMD value is 0.0010986328125.
# Fail to reject the null hypothesis with p-value: 0.88, the MMD value is -0.0035924911499023438.
# Fail to reject the null hypothesis with p-value: 0.25, the MMD value is 0.0012137889862060547.
# Fail to reject the null hypothesis with p-value: 0.16, the MMD value is 0.0023621320724487305.
# Reject the null hypothesis with p-value: 0.0, the MMD value is 0.015650153160095215.
# Fail to reject the null hypothesis with p-value: 0.67, the MMD value is -0.0024862289428710938.
# Reject the null hypothesis with p-value: 0.01, the MMD value is 0.010065317153930664.
# Fail to reject the null hypothesis with p-value: 0.26, the MMD value is 0.002850055694580078.
# Fail to reject the null hypothesis with p-value: 0.93, the MMD value is -0.00370633602142334.
# Power: 53/100
# Time taken: 255.8993 seconds
